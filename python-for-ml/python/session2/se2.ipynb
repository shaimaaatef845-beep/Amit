# %%
#task1
email = "Amit_ml@gmail.edu"

if email.count("@") == 1:

    username = email.split("@")[0]

    domain_part = email.split("@")[1]

    if "." in domain_part:

        domain = domain_part.split(".")[0]

        print("Username:", username)
        print("Domain:", domain)

        if email.endswith(".com"):
            print("Commercial Domain")
        elif email.endswith(".edu"):
            print("Educational Domain")
        else:
            print("Other Domain")

    else:
        print("Invalid email")

else:
    print("Invalid email")
# Out:
# Username: Amit_ml
# Domain: gmail
# Educational Domain

# %%
#task2
message = "####!!@mocleW EPGTQ!!!6789"

core = "mocleW EPGTQ"

words = core.split()

first_word = words[0][::-1]

second_word = words[1]

second_word = second_word.replace("E", "A")
second_word = second_word.replace("Q", "O")

print(first_word, second_word)
# Out:
# Welcom APGTO

# %%
#task3
message = "&&&***$ gnirts PLIO!!!@1234"

core = "gnirts PLIO"

words = core.split()

first_word = words[0][::-1]

second_word = words[1]

second_word = second_word.replace("I", "E")
second_word = second_word.replace("O", "U")

print(first_word, second_word)
# Out:
# string PLEU

# %%
#task4

message = "#####@yalpstecjorp EPUVT****9887"

core = "yalpstecjorp EPUVT"

words = core.split()

first_word = words[0][::-1]

second_word = words[1]

second_word = second_word.replace("E", "A")
second_word = second_word.replace("U", "O")

print(first_word, second_word)
# Out:
# projcetsplay APOVT
